# %% [markdown]
# <a href="https://colab.research.google.com/github/laura-caullo/DiploDatos2023/blob/main/1.An%C3%A1lisis_y_Visualizaci%C3%B3n/Consignas_Entregable_AyVD_Parte_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Diplomatura en Ciencia de Datos, Aprendizaje Automático y sus Aplicaciones**
#
# **Edición 2023**
#
# ---
# ## Trabajo práctico entregable - Parte 1

# %%
import io
import matplotlib
import matplotlib.pyplot as plt
import numpy
import pandas as pd
import seaborn

seaborn.set_context('talk')
pd.options.display.float_format = "{:.2f}".format

# %% [markdown]
# ## Lectura del dataset
#
# En la notebook 00 se explican los detalles de la siguiente sección.

# %%
url = 'https://raw.githubusercontent.com/DiploDatos/AnalisisyVisualizacion/master/sysarmy_survey_2022_processed.csv'
df = pd.read_csv(url)

# %%
df[:5]
# Out:
#   work_country work_province work_dedication             work_contract_type  \
# 0    Argentina     Catamarca       Full-Time      Staff (planta permanente)
# 1    Argentina         Chaco       Full-Time  Remoto (empresa de otro país)
# 2    Argentina         Chaco       Full-Time      Staff (planta permanente)
# 3    Argentina         Chaco       Full-Time  Remoto (empresa de otro país)
# 4    Argentina         Chaco       Full-Time      Staff (planta permanente)
#
#    salary_monthly_BRUTO  salary_monthly_NETO  numero  \
# 0             300000.00            245000.00    True
# 1             900000.00            850000.00    True
# 2             120000.00            115000.00    True
# 3             440000.00                 0.00    True
# 4             140000.00            125000.00    True
#
#                       salary_in_usd salary_last_dollar_value  \
# 0                               NaN                      NaN
# 1  Cobro todo el salario en dólares                      300
# ...

# %%
df1 = df[df["salary_in_usd"] == 'Cobro todo el salario en dólares']
df1[['salary_monthly_BRUTO','salary_monthly_NETO','salary_in_usd']].sort_values(by = 'salary_monthly_BRUTO',ascending = False)
# Out:
#       salary_monthly_BRUTO  salary_monthly_NETO  \
# 4507           28000000.00           2500000.00
# 3086            8000000.00           8000000.00
# 4775            5015000.00                 0.00
# 4397            3300000.00           3300000.00
# 1369            3150000.00           3000000.00
# ...                    ...                  ...
# 4029                  0.00                 0.00
# 2276                  0.00            180300.00
# 4637                  0.00                 0.00
# 2849                  0.00                 0.00
# 3786                  0.00                 0.00
#
#                          salary_in_usd
# 4507  Cobro todo el salario en dólares
# 3086  Cobro todo el salario en dólares
# 4775  Cobro todo el salario en dólares
# 4397  Cobro todo el salario en dólares
# 1369  Cobro todo el salario en dólares
# ...                                ...
# 4029  Cobro todo el salario en dólares
# 2276  Cobro todo el salario en dólares
# ...

# %%
df.shape
# Out:
# (5358, 44)

# %%
df.dtypes.reset_index()
# Out:
#                                                 index        0
# 0                                        work_country   object
# 1                                       work_province   object
# 2                                     work_dedication   object
# 3                                  work_contract_type   object
# 4                                salary_monthly_BRUTO  float64
# 5                                 salary_monthly_NETO  float64
# 6                                              numero     bool
# 7                                       salary_in_usd   object
# 8                            salary_last_dollar_value   object
# 9                                   salary_pay_cripto   object
# 10                                    salary_%_cripto   object
# 11                                   salary_has_bonus   object
# 12                               salary_bonus_tied_to   object
# 13                        salary_inflation_adjustment   object
# ...

# %% [markdown]
# # Ejercicio 1 - Análisis descriptivo
#
# Responder a la pregunta: **¿Cuáles son los lenguajes de programación asociados a los mejores salarios?**
#
# Para ello:
# 1. Seleccionar las columnas relevantes para analizar.
# 2. Seleccionar las filas relevantes para analizar. Esto incluye la eliminación de valores extremos y erróneos, pero también puede enfocar el análisis en una sub-población. Por ejemplo, se pueden limitar a personas con un salario mayor que 10000 pesos, o a las personas que trabajan sólo en "Data Science", pero deben justificar su elección y reformular la pregunta inicial de ser necesario.
#   * Obtener una lista de los lenguajes de programación más populares. Decidir cuántos y cuáles seleccionan para incluir en el análisis.
#   * Para cada una de las otras columnas del punto anterior, elegir los rangos o valores seleccionan para incluir en el análisis.
# 3. Seleccionar métricas que ayuden a responder la pregunta, y los métodos para analizarlas. Elegir UNA de las siguientes opciones:
#   * Comparar las distribuciones de salario para cada lenguaje utilizando visualizaciones. Como la visualización es el producto final, debe ser clara y mostrar información relevante.
#   * Comparar medidas de estadística descriptiva sobre la distribución de salario para cada lenguaje. Sean creativos, la estadística descriptiva nos permite decir cosas como: "el 10% de los mejores sueldos los ganan, en su mayoría, programadores que saben kotlin!" (donde *mayoría* es un término medio engañoso que sólo significa más del 50%). Para comparar múltiples lenguajes, les recomendamos usar también visualizaciones.
#   * Comparar probabilidades. Por ejemplo: "Si sabés Python o Java, tenés un 30% más de chances de ganar arriba de 100K".
#
# Si lo consideran necesario, realicen varias iteraciones. Es decir, si encuentran que las distribuciones de los lenguajes de programación que seleccionaron inicialmente no son muy diferentes, pueden re-hacer el análisis usando sólo los lenguajes de programación que son diferentes.

# %%
# complete here if you want to include more columns
relevant_columns = ['tools_programming_languages', 'salary_monthly_NETO','salary_monthly_BRUTO','work_dedication']

# %%
casos_raros = df[df['salary_monthly_NETO'] > df['salary_monthly_BRUTO']]
casos_raros.shape
# Out:
# (216, 44)

# %%
casos_iguales = df[df['salary_monthly_NETO'] == df['salary_monthly_BRUTO']]
casos_iguales.shape
# Out:
# (505, 44)

# %%
full_time = df[df['work_dedication'] == "Full-Time"]
full_time.shape
# Out:
# (5106, 44)

# %%
df_limpio = full_time[full_time['salary_monthly_NETO']<=full_time['salary_monthly_BRUTO']]
q05 = df_limpio['salary_monthly_BRUTO'].quantile(0.05)
q95 = df_limpio['salary_monthly_BRUTO'].quantile(0.95)
df_limpio = df_limpio[(q05 < df_limpio['salary_monthly_BRUTO']) & (df_limpio['salary_monthly_BRUTO']< q95)]
df_limpio['salary_monthly_BRUTO'].describe()
# Out:
# count      4408.00
# mean     323410.99
# std      206050.89
# min        5250.00
# 25%      172999.75
# 50%      270000.00
# 75%      400000.00
# max     1110000.00
# Name: salary_monthly_BRUTO, dtype: float64

# %%
seaborn.pairplot(data=df_limpio, y_vars=['salary_monthly_BRUTO'],
                 x_vars=['salary_monthly_NETO'],
                 aspect=2, height=4)

# %%
plt.hist(df_limpio['salary_monthly_BRUTO'], rwidth=0.8)
plt.xlabel('Salario')
plt.ylabel('Personas')
plt.title('Histogram')
plt.xlim((0,950000))
plt.show()

# %% [markdown]
# ### Conteo de frecuencias de los lenguajes de programación
#
# La columna que contiene información sobre los lenguajes de programación utilizados es `tools_programming_languages`. Sus valores son strings con los lenguajes seleccionados separados por comas.

# %%
df.tools_programming_languages[:3]
# Out:
# 0                                          Python
# 1    CSS, HTML, Java, Javascript, SQL, TypeScript
# 2                         Javascript, PHP, Python
# Name: tools_programming_languages, dtype: object

# %% [markdown]
# Las siguientes celdas de código separan estos lenguajes de programación y cuentan la frecuencia con la que aparecen.
#
# No es necesario entender este código en profundidad, aunque sí es un buen ejercicio.

# %%
# Convert the comma-separated string of languages to a list of string.
# Remove 'ninguno de los anteriores' option, spaces and training commas.
def split_languages(languages_str):
  if not isinstance(languages_str, str):
    return []
  # Remove 'other' option
  languages_str = languages_str.lower()\
    .replace('ninguno de los anteriores', '')
  # Split string into list of items
  # Remove spaces and commas for each item
  return [lang.strip().replace(',', '')
          for lang in languages_str.split()]

# Create a new column with the list of languages
df_limpio.loc[:, 'cured_programming_languages'] = df_limpio.tools_programming_languages\
    .apply(split_languages)
if 'cured_programming_languages' not in relevant_columns:
    relevant_columns.append('cured_programming_languages') 

# Duplicate each row of df for each programming language
# mentioned in the response.
# We only include in df_lang the columns we are going to analyze later, so we
# don't duplicate innecesary information.
df_lang = df_limpio.cured_programming_languages\
    .apply(pd.Series).stack()\
    .reset_index(level=-1, drop=True).to_frame()\
    .join(df_limpio[relevant_columns])\
    .rename(columns={0: 'programming_language'})
# Horrible programming style! But a lot of data science code can be written with
# as concatenations of functions (pipelines), and there's no elegant way of
# doing that on Python.
df_lang[:5]
# Out:
# <ipython-input-39-640772986bb5>:24: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_lang = df_limpio.cured_programming_languages\
#   programming_language                   tools_programming_languages  \
# 0               python                                        Python
# 1                  css  CSS, HTML, Java, Javascript, SQL, TypeScript
# 1                 html  CSS, HTML, Java, Javascript, SQL, TypeScript
# 1                 java  CSS, HTML, Java, Javascript, SQL, TypeScript
# 1           javascript  CSS, HTML, Java, Javascript, SQL, TypeScript
#
#    salary_monthly_NETO  salary_monthly_BRUTO work_dedication  \
# 0            245000.00             300000.00       Full-Time
# 1            850000.00             900000.00       Full-Time
# 1            850000.00             900000.00       Full-Time
# ...

# %%
df_lang.shape
# Out:
# (12157, 6)

# %% [markdown]
# En la columna `programming_language` se encuentra cada lenguaje por separado. Notar que si una respuesta contenía 3 lenguajes, como `"HTML, Javascript, Python"`, la fila ha sido replicada 3 veces. Por ello, hay tres filas con índice 1.

# %%
language_count = df_lang.programming_language.value_counts()\
    .reset_index()\
    .rename(columns={'index': 'language', 'programming_language': 'frequency'})
language_count[:20]
# Out:
#       language  frequency
# 0   javascript       1753
# 1          sql       1744
# 2         html       1280
# 3       python       1149
# 4          css        871
# 5         java        815
# 6   typescript        751
# 7   bash/shell        701
# 8         .net        538
# 9          php        493
# 10          c#        438
# 11          go        211
# 12      kotlin        143
# 13         vba        125
# 14         c++        118
# 15           c         89
# 16      groovy         84
# 17        ruby         79
# 18           r         68
# 19       swift         58

# %% [markdown]
# ## Filtrado de lenguajes relevantes
#
# El siguiente código permite seleccionar sólo las filas donde el valor de la columna `programming_language` se encuentre en la lista `interesting_languages`.

# %%
# Filter out languages that we want to exclude
# Complete here with your selected list.
interesting_languages = language_count["language"][:20]
filtered_df_lang = df_lang[df_lang.programming_language.isin(interesting_languages)]
filtered_df_lang[:5]
# Out:
#   programming_language                   tools_programming_languages  \
# 0               python                                        Python
# 1                  css  CSS, HTML, Java, Javascript, SQL, TypeScript
# 1                 html  CSS, HTML, Java, Javascript, SQL, TypeScript
# 1                 java  CSS, HTML, Java, Javascript, SQL, TypeScript
# 1           javascript  CSS, HTML, Java, Javascript, SQL, TypeScript
#
#    salary_monthly_NETO  salary_monthly_BRUTO work_dedication  \
# 0            245000.00             300000.00       Full-Time
# 1            850000.00             900000.00       Full-Time
# 1            850000.00             900000.00       Full-Time
# 1            850000.00             900000.00       Full-Time
# 1            850000.00             900000.00       Full-Time
#
#                       cured_programming_languages
# 0                                        [python]
# 1  [css, html, java, javascript, sql, typescript]
# ...

# %%
df_agrupado = filtered_df_lang.groupby('programming_language').agg({'salary_monthly_BRUTO' : ['mean','median','std', 'min','max']})
df_agrupado = df_agrupado.reset_index()
df_agrupado['salary_monthly_BRUTO'] = df_agrupado['salary_monthly_BRUTO'].round()
df_agrupado = df_agrupado.sort_values(by = ('salary_monthly_BRUTO','mean'),ascending = False)
df_agrupado = df_agrupado.reset_index(drop = True)
df_agrupado = df_agrupado.rename(columns = {'programming_language':'lenguajes_populares','salary_monthly_BRUTO': 'describe_salario_bruto'})
df_agrupado[('describe_salario_bruto','CV')] = df_agrupado[('describe_salario_bruto','std')] / df_agrupado[('describe_salario_bruto','mean')]
df_agrupado
# Out:
#    lenguajes_populares describe_salario_bruto                                \
#                                          mean    median       std       min
# 0                   go              461813.00 400000.00 243658.00   8000.00
# 1                 ruby              433786.00 392000.00 251989.00   8000.00
# 2               kotlin              432089.00 368000.00 257142.00  80000.00
# 3                swift              394096.00 318000.00 263078.00  70200.00
# 4               python              366504.00 312000.00 216584.00   5500.00
# 5               groovy              361362.00 330000.00 197750.00 100000.00
# 6                 java              356490.00 314427.00 215499.00  10000.00
# 7           bash/shell              352274.00 300000.00 210565.00   5500.00
# 8                    c              339268.00 300000.00 210517.00  60000.00
# 9                    r              338945.00 267000.00 209916.00  10000.00
# ...

# %%
cant_leng = df_lang.reset_index().groupby('index').size().reset_index(name='cant_leng')
df_int = df_lang.reset_index()
df_int = df_int.merge(cant_leng, on='index')
df_int = df_int.rename(columns={'index': 'persona'})
df_int[['persona','cant_leng','programming_language']]
# Out:
#        persona  cant_leng programming_language
# 0            0          1               python
# 1            1          6                  css
# 2            1          6                 html
# 3            1          6                 java
# 4            1          6           javascript
# ...        ...        ...                  ...
# 12152     5352          1                  sql
# 12153     5355          2                 html
# 12154     5355          2                  sql
# 12155     5356          2           javascript
# 12156     5356          2                  sql
#
# [12157 rows x 3 columns]

# %%
per = df_int[['persona','cant_leng']].drop_duplicates()
per = per['cant_leng'].value_counts().reset_index(name = 'cant_pers')
per = per.rename(columns = {'index':'cant_leng'}).sort_values(by = 'cant_leng').reset_index(drop = True)
per
# Out:
#     cant_leng  cant_pers
# 0           1        774
# 1           2        791
# 2           3        685
# 3           4        543
# 4           5        380
# 5           6        251
# 6           7        138
# 7           8         66
# 8           9         33
# 9          10         13
# 10         11          6
# 11         12          2
# 12         13          7
# 13         15          2
# 14         16          1
# 15         20          1

# %%
# Creamos el gráfico de barras
graf = per[:10]
plt.figure(figsize=(7, 5))
plt.bar(graf['cant_leng'], graf['cant_pers'])
plt.xticks(graf['cant_leng'], graf['cant_leng'])
# Añadimos etiquetas y títulos
plt.xlabel('Cantidad de lenguajes')
plt.ylabel('Programadores')
plt.title('Cuantos lenguajes saben los programadores?')

# Mostramos el gráfico
plt.show()

# %%
sal = df_int[['salary_monthly_BRUTO','cant_leng']].drop_duplicates()
sal = sal.groupby('cant_leng').agg({'salary_monthly_BRUTO' : ['mean','median','std', 'min','max']}).reset_index()
sal = sal.rename(columns= {"salary_monthly_BRUTO": "salario_bruto_medio"}).round()
sal[:10]
# Out:
#   cant_leng salario_bruto_medio
#                            mean    median       std       min        max
# 0         1           325510.00 275176.00 210663.00   5300.00 1100000.00
# 1         2           350453.00 289000.00 224072.00   5500.00 1100000.00
# 2         3           351974.00 290000.00 234355.00   7000.00 1110000.00
# 3         4           346953.00 277500.00 233676.00   5700.00 1100000.00
# 4         5           359226.00 305500.00 228976.00  50000.00 1110000.00
# 5         6           328889.00 280000.00 220362.00  55000.00 1100000.00
# 6         7           309798.00 274000.00 185686.00  10000.00 1000000.00
# 7         8           349529.00 287169.00 211328.00  75000.00 1000000.00
# 8         9           389417.00 344500.00 245257.00  80000.00 1000000.00
# 9        10           287299.00 290000.00 107729.00 150000.00  471210.00

# %%
# Creamos el gráfico de barras
plt.figure(figsize=(10, 6))
plt.bar(sal['cant_leng'], sal['salario_bruto_medio'])
plt.xticks(sal['cant_leng'], sal['cant_leng'])
# Añadimos etiquetas y títulos
plt.xlabel('Cantidad de lenguajes')
plt.ylabel('Salario medio')
plt.title('Salario medio por cantidad de lenguajes')

# Mostramos el gráfico
plt.show()

# %%
df_filtrado = df_int[df_int['cant_leng']==1]
mariano = df_filtrado['programming_language'].value_counts().reset_index(name = 'cant_pers')
mariano = mariano.rename(columns = {'index' : 'lenguaje'})
mariano = mariano[mariano['cant_pers']>10]
best_lenguajes = mariano['lenguaje'].tolist()
mariano
# Out:
#       lenguaje  cant_pers
# 0          sql        179
# 1       python        150
# 2         java         88
# 3   javascript         84
# 4   bash/shell         78
# 5         abap         20
# 6         html         17
# 7        swift         16
# 8           go         14
# 9   typescript         13
# 10      kotlin         13
# 11         php         12

# %%
df_fil_res = df_filtrado.groupby('programming_language').agg({'salary_monthly_BRUTO' : ['mean','median','std', 'min','max']})
df_fil_res = df_fil_res.reset_index()
df_fil_res['salary_monthly_BRUTO'] = df_fil_res['salary_monthly_BRUTO'].round()
df_fil_res = df_fil_res.sort_values(by = ('salary_monthly_BRUTO','mean'),ascending = False)
df_fil_res = df_fil_res.reset_index(drop = True)
df_fil_res = df_fil_res.rename(columns = {'programming_language':'lenguajes_populares','salary_monthly_BRUTO': 'describe_salario_bruto'})
df_fil_res[('describe_salario_bruto','CV')] = df_fil_res[('describe_salario_bruto','std')] / df_fil_res[('describe_salario_bruto','mean')]
df_fil_res = df_fil_res[df_fil_res['lenguajes_populares'].isin(best_lenguajes)]
df_fil_res
# Out:
#    lenguajes_populares describe_salario_bruto                                \
#                                          mean    median       std       min
# 6                   go              409406.00 354103.00 174648.00 138000.00
# 7               python              402717.00 325000.00 241251.00  80000.00
# 16          javascript              328815.00 256608.00 239639.00  60000.00
# 18                java              319554.00 283572.00 198052.00  90000.00
# 22                abap              311030.00 317500.00 105107.00  90000.00
# 23               swift              308389.00 256500.00 198254.00 109000.00
# 25              kotlin              292231.00 325000.00 104127.00 100000.00
# 28          bash/shell              264915.00 241872.00 132363.00  78800.00
# 30                 sql              251292.00 217000.00 148898.00  63000.00
# 32          typescript              245946.00 200000.00 191533.00   5300.00
# ...

# %% [markdown]
# # Ejercicio 2 - Densidades y varias variables
#
# Responder a la pregunta general: **¿Que herramientas (prácticas y teóricas) són útiles para explorar la base, descubrir patrones, asociaciones?**
#
# Para ello considere (igual al ejercicio Anterior):
# 1. Seleccionar las columnas relevantes para analizar.
# 2. Seleccionar las filas relevantes para analizar. Esto incluye la eliminación de valores extremos y erróneos, pero también puede enfocar el análisis en sub-poblaciones.

# %% [markdown]
# ## a) Densidad conjunta
#
# Que herramientas visuales y modelos puede utilizar para estudiar la distribución y comportamiento de sus datos?
#
# Elija tres variables numéricas y 2 variables categóricas. Visualice la base según varias de las variables elegidas. Puede describir de alguna forma el comportamiento de sus datos? Que herramientas utilizaría? Describa

# %% [markdown]
# ## b) Asociación
#
# * Necesitamos decidir si sacar o no la columna de salario bruto. Para hacer la encuesta más simple.
# ¿Existe una correlación entre el salario bruto y el neto? Que abordaje y medidas usaría

# %% [markdown]
# ## c) Densidad condicional
#
# Estudie la distribución del salario según el nivel de estudio.
#
# Separe la población según el nivel de estudio (elija dos subpoblaciones numerosas) y grafique de manera comparativa ambos histogramas de la variable `'salary_monthly_NETO'`
# ¿Considera que ambas variables son independientes?
# ¿Qué analizaría al respecto?
#
# Calcule medidas de centralización y dispersión para cada subpoblación

# %% [markdown]
# ## d) Densidad Conjunta condicional
#
# Elija dos variables numéricas y una categórica.
# Estudie la dispersión (scatterplot) de las dos variables discriminando en color por la variable categórica (ayuda: hue en seaborn)
